# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img_raw = cv2.imread('abcd.jpeg')

# %%
type(img_raw)
# Out:
# numpy.ndarray

# %%
img_raw.shape
# Out:
# (780, 906, 3)

# %%
plt.matshow(img_raw)

# %%
test_image_gray = cv2.cvtColor(img_raw, cv2.COLOR_BGR2GRAY)

# %%
plt.matshow(test_image_gray)

# %%
plt.imshow(test_image_gray, cmap='gray')

# %%
haar_cascade_face = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);
print(faces_rects)
# Out:
# [[328 114 140 140]]

# %%
roi_gray = test_image_gray[y:y+h, x:x+w]
roi_color = img_raw [y:y+h, x:x+w]

# %%
eyes = eye_cascade.detectMultiScale(roi_gray)
print(eyes)
# Out:
# [[67 21 51 51]]

# %%
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  1

# %%
for (x,y,w,h) in faces_rects:
     a = cv2.rectangle(img_raw, (x, y), (x+w, y+h), (0, 255, 0), 2)
for (ex,ey,ew,eh) in eyes:
    A = cv2.rectangle(a,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

# %%
plt.matshow(A)
