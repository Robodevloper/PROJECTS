# %% [markdown]
# <b>HANDWRITTEN DIGIT RECONGNITION PROJECT</b>
#
# I m using MNIST dataset  for this project , that contain 70,000 images of 0 to 9 number
#
# x_train = 60,000 <br>
# x_test = 10,000

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
plt.matshow(X_train[0])

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
plt.figure(figsize=(10,10))

for i in range(10):
    
    plt.subplot(5,5,i+1)
    
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    
    plt.imshow(X_train[i], cmap=plt.cm.binary)
   
    ##plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s 95us/sample - loss: 2.2416 - acc: 0.6164
# Epoch 2/5
# 60000/60000 [==============================] - 6s 94us/sample - loss: 2.0913 - acc: 0.7477
# Epoch 3/5
# 60000/60000 [==============================] - 6s 94us/sample - loss: 1.9006 - acc: 0.7697
# Epoch 4/5
# 60000/60000 [==============================] - 6s 95us/sample - loss: 1.7124 - acc: 0.7817
# Epoch 5/5
# 60000/60000 [==============================] - 6s 94us/sample - loss: 1.5490 - acc: 0.7888

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 10000/10000 [==============================] - 1s 54us/sample - loss: 1.4624 - acc: 0.8077
# [1.4624467315673828, 0.8077]

# %%
y_predicted = model.predict(X_test_flattened)
y_predicted[0]
# Out:
# array([0.04020178, 0.05947375, 0.04959407, 0.06345013, 0.08279195,
#        0.05811265, 0.03689253, 0.299155  , 0.05645385, 0.12743464],
#       dtype=float32)

# %%
np.argmax(y_predicted[0])
# Out:
# 7

# %%
plt.matshow(X_test[0])

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]

# %%
y_predicted_labels[:5]
# Out:
# [7, 2, 1, 0, 4]

# %% [markdown]
# <b>using hidden layer</b>

# %%
model = keras.Sequential([
    keras.layers.Dense(100, input_shape=(784,), activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 13s 211us/sample - loss: 1.2508 - acc: 0.7082
# Epoch 2/5
# 60000/60000 [==============================] - 13s 219us/sample - loss: 0.5422 - acc: 0.8630
# Epoch 3/5
# 60000/60000 [==============================] - 13s 223us/sample - loss: 0.4175 - acc: 0.8882
# Epoch 4/5
# 60000/60000 [==============================] - 14s 230us/sample - loss: 0.3680 - acc: 0.8978
# Epoch 5/5
# 60000/60000 [==============================] - 14s 226us/sample - loss: 0.3412 - acc: 0.9039

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 10000/10000 [==============================] - 1s 79us/sample - loss: 0.3204 - acc: 0.9090
# [0.32039249727129937, 0.909]

# %%
y_predict = model.predict(X_test_flattened)

# %%
np.argmax(y_predict[3000])
# Out:
# 6

# %%
plt.matshow(X_test[3000])
